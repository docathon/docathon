# %%
import pandas as pd
from tabulate import tabulate
import shutil as sh
import numpy as np
from IPython.display import HTML

# %%
def make_bold(a):
    return '**{}**'.format(a)

# %%
pd.set_option('display.max_colwidth', 100)

# %%
data = pd.read_csv('./data/Schedule - Sheet1.csv', index_col=0, skiprows=[1])
data.index.name = 'time'
data = data.replace(np.nan, '--')
# data.columns = data.columns.map(make_bold)
# data.index = data.index.map(make_bold)

# %%
# table = tabulate(data, tablefmt='pipe', headers=data.columns,
#                  numalign='center', stralign='center')
def make_center(a):
    return 'text-align: center'
style = data.style.applymap(make_center)


def hover(hover_color="#ffff99"):
    return dict(selector="tr:hover",
                props=[("background-color", "%s" % hover_color)])

styles = [
    hover(),
    dict(selector="th", props=[("font-size", "120%"),
                               ("text-align", "center")]),
    dict(selector="td", props=[("width", "100px")])
]
style = style.set_table_styles(styles)

# %%
table = style.render()
table = '\n'.join(ii.strip() for ii in table.split('\n'))

# %%
style
# Out:
#         <style  type="text/css" >
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1 tr:hover {
#
#                 background-color: #ffff99;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1 th {
#
#                 font-size: 120%;
#
#                 text-align: center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1 td {
#
#                 width: 1000px;
#
#             }
#
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row0_col0 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row0_col1 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row0_col2 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row0_col3 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row0_col4 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row1_col0 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row1_col1 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row1_col2 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row1_col3 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row1_col4 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row2_col0 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row2_col1 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row2_col2 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row2_col3 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row2_col4 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row3_col0 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row3_col1 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row3_col2 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row3_col3 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row3_col4 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row4_col0 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row4_col1 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row4_col2 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row4_col3 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row4_col4 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row5_col0 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row5_col1 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row5_col2 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row5_col3 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row5_col4 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row6_col0 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row6_col1 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row6_col2 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row6_col3 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row6_col4 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row7_col0 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row7_col1 {
#
#                 text-align:  center;
#
#                 text-align:  center;
#
#             }
#
#             #T_1169adb4_efb4_11e6_9e6e_20c9d077fbe1row7_col2 {
#
#                 text-align:

# %%
with open('./data/bids.md', 'r') as ff:
    lines = ff.readlines()

for ii, line in enumerate(lines):
    if '###SCHEDULE###' in line:
        print(line)
        lines[ii] = table
        lines.insert(ii+1, '\n')

with open('../content/pages/hosts/bids.md', 'w') as ff:
    ff.writelines(lines)
# Out:
# ###SCHEDULE###
